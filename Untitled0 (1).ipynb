# %%
print("襪子是世界上最胖的貓")
# Out:
# 襪子是世界上最胖的貓

# %%
num1=int(input())
num2=int(input())
print(num2+num1)
# Out:
# 100
# 67
# 167

# %%
num1=100
num2=10
print(num1+num2)
# Out:
# 110

# %%
a=input()
b="你好"
print(a+b)
# Out:
# 襪子
# 襪子你好

# %%
a="襪子"
b="好胖"
print(a+b)
# Out:
# 襪子好胖

# %%
print("Hello world")
# Out:
# Hello world
